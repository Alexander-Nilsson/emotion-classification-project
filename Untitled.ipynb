# %%
import os
import math
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
from tqdm.notebook import tqdm
import numpy as np

from torch.utils.data import DataLoader, random_split
from torchvision.utils import save_image
from torchvision.io import read_image
from torchvision.transforms import Resize
from torchvision.transforms import Compose, ToTensor, Lambda, Pad
import torch.optim as optim
from PIL import Image
nn = torch.nn
F = nn.functional

# %%
# %run faceDetection.ipynb
# Out:
# 2548
# 2548
# 2548
# Number of samples in the dataset:  2548
# 27

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True, classes = 1
                      )
# Out:
# Using cache found in /home/oscer102/.cache/torch/hub/ultralytics_yolov5_master
# requirements: Ultralytics requirement ['pillow>=10.3.0'] not found, attempting AutoUpdate...
#   WARNING: Failed to remove contents in a temporary directory '/home/oscer102/.local/lib/python3.12/site-packages/~IL'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/home/oscer102/.local/lib/python3.12/site-packages/~illow.libs'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# facenet-pytorch 2.6.0 requires Pillow<10.3.0,>=10.2.0, but you have pillow 10.3.0 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pillow>=10.3.0
#   Downloading pillow-10.3.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Downloading pillow-10.3.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
# Successfully installed pillow-10.3.0
#
# requirements: AutoUpdate success ✅ 11.4s, installed 1 package: ['pillow>=10.3.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 2024-5-14 Python-3.12.2 torch-2.2.1 CUDA:0 (NVIDIA GeForce GTX 1080, 8111MiB)
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:70, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      69 if pretrained:
# ---> 70     ckpt = torch.load(attempt_download(path), map_location=device)  # load
#      71     csd = ckpt["model"].float().state_dict()  # checkpoint state_dict as FP32
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:1438, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1437 unpickler.persistent_load = persistent_load
# -> 1438 result = unpickler.load()
#    1440 torch._utils._validate_loaded_sparse_tensors()
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:1408, in _load.<locals>.persistent_load(saved_id)
#    1407     nbytes = numel * torch._utils._element_size(dtype)
# -> 1408     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1410 return typed_storage
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:1382, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1379 # TODO: Once we decide to break serialization FC, we can
#    1380 # stop wrapping with TypedStorage
#    1381 typed_storage = torch.storage.TypedStorage(
# -> 1382     wrap_storage=restore_location(storage, location),
#    1383     dtype=dtype,
#    1384     _internal=True)
#    1386 if typed_storage._data_ptr() != 0:
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:1311, in _get_restore_location.<locals>.restore_location(storage, location)
#    1310 def restore_location(storage, location):
# -> 1311     return default_restore_location(storage, str(map_location))
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:391, in default_restore_location(storage, location)
#     390 for _, _, fn in _package_registry:
# --> 391     result = fn(storage, location)
#     392     if result is not None:
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/serialization.py:271, in _cuda_deserialize(obj, location)
#     270 else:
# --> 271     return obj.cuda(device)
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/_utils.py:115, in _cuda(self, device, non_blocking, **kwargs)
#     114 else:
# --> 115     untyped_storage = torch.UntypedStorage(
#     116         self.size(), device=torch.device("cuda")
#     117     )
#     118     untyped_storage.copy_(self, non_blocking)
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True, classes = 1
#       2                       )
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/hub.py:566, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     562 if source == 'github':
#     563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     564                                        verbose=verbose, skip_validation=skip_validation)
# --> 566 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     567 return model
#
# File /courses/TDDE70/miniconda3/envs/tdde70/lib/python3.12/site-packages/torch/hub.py:595, in _load_local(hubconf_dir, model, *args, **kwargs)
#     592     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     594     entry = _load_entry_from_hubconf(hub_module, model)
# --> 595     model = entry(*args, **kwargs)
#     597 return model
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:102, in yolov5s(pretrained, channels, classes, autoshape, _verbose, device)
#      98 def yolov5s(pretrained=True, channels=3, classes=80, autoshape=True, _verbose=True, device=None):
#      99     """Creates YOLOv5-small model with options for pretraining, input channels, class count, autoshaping, verbosity, and
#     100     device.
#     101     """
# --> 102     return _create("yolov5s", pretrained, channels, classes, autoshape, _verbose, device)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:83, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      81 help_url = "https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading"
#      82 s = f"{e}. Cache may be out of date, try `force_reload=True` or see {help_url} for help."
# ---> 83 raise Exception(s) from e
#
# Exception: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# . Cache may be out of date, try `force_reload=True` or see https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading for help.

# %%
print(model)

# %%
import cv2
batch_size = 1  # Set your desired batch size
shuffle = True   # Set whether you want to shuffle the 
num_workers = 4  # Set the number of processes to load data
num_classes = 30
learning_rate = 0.005
device = 'cuda' if torch.cuda.is_available() else 'cpu'
#model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
optimizer = optim.Adam(model.parameters(), lr = learning_rate)
model = model.to(device)
train_size = int(0.8 * len(dataset))
#print(len(dataset))
#print(train_size)
val_size = len(dataset) - train_size
#print(val_size)
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
epoch = 0

lbar = tqdm(train_loader)
lbar.set_description(f"Epoch {epoch}")
for batch_idx, (samples_batch, labels_batch, num_faces) in enumerate(lbar):
    samples_batch, labels_batch, num_faces = samples_batch.to(device), labels_batch.to(device), num_faces.to(device)

    print(samples_batch.shape)
    samples_batch = samples_batch.permute(0,3,1,2).float()  # Convert to numpy array

    output = model(samples_batch)
    break
print("klar")
#print(output)
#print(output) #list of tensors as output
print(output[2].shape)
plt.imshow(output)
#output[1].show()
#print(output.shape())

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
print(imgs)
# Inference
results = model(imgs)

# Results
results.print()
results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define training parameters
batch_size = 8
learning_rate = 0.001
num_epochs = 50

# Prepare dataset and dataloaders

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# Define the YOLOv5 model architecture
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model = model.to(device)

# Define optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = ...

# Training loop
for epoch in range(num_epochs):
    # Training
    model.train()
    for batch_idx, (images, targets, a) in enumerate(train_loader):
        images, targets = images.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(images.permute(0, 3, 1, 2).float())
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Step [{batch_idx}/{len(train_loader)}], Loss: {loss.item()}')

    # Validation
    model.eval()
    with torch.no_grad():
        for images, targets in val_loader:
            images, targets = images.to(device), targets.to(device)
            outputs = model(images)
            # Evaluation metrics

# Save trained model
#torch.save(model.state_dict(), 'yolov5_face_detection.pth')
